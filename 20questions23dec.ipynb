# %% [markdown]
# 1. you have to write a fun while will take string and return the length of a strig with out using built in fun LEN.
# 2. write a fun which will be able to print an index of all premitive element which will pass
# 3. Write a func which will take input as a dict and give me out as a list of all the values even in case of 2 level nesting it should work.
# 4. Write a func which will take another func as an input and retuen me an output
# 5. write a function which will take list as a input and give me concatination of all the element as an output
# 6. Write a function which will take list as an input return index of each of element like a built in index function but even if we have repettive element it should return index
# 7. Write a func which will return list of all the file name from directory
# 8. waf which will be show your system configuration
# 9. waf which will be show date and time
# 10. waf wihich ill be able to read an image file and show it to you
# 11. waf which will read a video file and play for you.
# 12. waf which can move a file from on directry to another directory
# 13. waf which will be shutdown your system
# 14. waf by which I can sen the mail to anyone
# 15. waf by which will be access your Mail
# 16. waf to read a complete PDF file
# 17. waf o read a word file
# 18. waf which can help you to filter only word file from one directory
# 19. waf by which you can print an IP addresss of your system
# 20. waf by which you will be able to append two pdf files

# %%
def ques1(a):
    count=0
    for i in a:
        count+=1
    print(count)

# %%
ques1("srimanta")
# Out:
# 8

# %%
a=['ds','dsfe',12,33,56.6]

# %%
for i in a:
    print(a.index(i),i)
# Out:
# 0 ds
# 1 dsfe
# 2 12
# 3 33
# 4 56.6

# %%
def ques2(a):
    for i in a:
        #if type(i)==int or type(i)==chr or type(i)==float:
        if type(i)!= list and type(i) != str and type(i) != set and type(i) != dict and type(i) !=tuple:
            print(a.index(i),i)

# %%
ab=[11,22,33,44,'d','ede',5.66,[4,32,5],(1,22,34,5.7),"e"]
type(ab[5])
# Out:
# str

# %%
ques2(ab)
# Out:
# 0 11
# 1 22
# 2 33
# 3 44
# 6 5.66

# %%
a= {'a':12,'b':13,'c':16,'d':54,'e':{'z':12,'y':355}}

# %%
b=a.values()

# %%
b
# Out:
# dict_values([12, 13, 16, 54, {'z': 12, 'y': 355}])

# %%
def ques3(a):
    b=a.values()
    l=[]
    for i in b:
        if type(i)==dict:
            for j in i.values():
                l.append(j)
        else:
            l.append(i)
    print(l)

# %%
ques3(a)
# Out:
# [12, 13, 16, 54, 12, 355]

# %%
def ques4(a):
    return a+2
def ques4a(b):
    return b**2

# %%
ques4a(ques4(2))
# Out:
# 16

# %%
a='ff'
a+str(11)
# Out:
# 'ff11'

# %%
def ques5(a):
    s=''
    if type(a)==list:
        for i in a:
            s=s+str(i)
        print(s)

# %%
a=[11,2,5,'dd']

# %%
ques5(a)
# Out:
# 1125dd

# %%
l=[11,22,33,11,'d',[11,22,3],'e',{'a':12,'b':67}]
l.index(11)
# Out:
# 0

# %%
def ques6(a):
    count=0
    for i in a:
        print("index :"+count,i)
        count=count+1

# %%
ques6(l)
# Out:
# 0 11
# 1 22
# 2 33
# 3 11
# 4 d
# 5 [11, 22, 3]
# 6 e
# 7 {'a': 12, 'b': 67}

# %%
def ques7(path):
    import os
    dir_list=os.listdir(path)
    print("all the files in: "+path+"\n")
    print(dir_list)

# %%
ques7("D:\Wallpapers")
# Out:
# all the files in: D:\Wallpapers
#
# ...

# %%
def ques8():    
    import platform
    print("System: "+platform.machine())
    print("Node_name :"+platform.node())
    print("Release :"+platform.release())
    print("Version :"+platform.version())
    print("Machine :"+platform.machine())
    print("processor :"+platform.processor())

# %%
ques8()
# Out:
# System: AMD64
# Node_name :DESKTOP-2QVA9N0
# Release :10
# Version :10.0.19044
# Machine :AMD64
# processor :AMD64 Family 23 Model 17 Stepping 0, AuthenticAMD

# %%
ques8()
# Out:
# System: AMD64
# Node_name :DESKTOP-2QVA9N0
# Release :10
# Version :10.0.19044
# Machine :AMD64
# processor :AMD64 Family 23 Model 17 Stepping 0, AuthenticAMD

# %%
def ques9():
    import datetime
    print("current date and time: ")
    now=datetime.datetime.now()
    print(now)

# %%
ques9()
# Out:
# current date and time:
# 2022-01-08 21:28:52.509424

# %%
def ques10():
    from IPython.display import Image
    img=Image(filename=r"C:\Users\USER\OneDrive\Desktop\champ.jpg")
    display(img)

# %%
ques10()

# %%
from IPython.display import Image,display

# %%
listofimgs=[r"C:\Users\USER\OneDrive\Desktop\champ.jpg",r"C:\Users\USER\OneDrive\Desktop\ss2.png"]

# %%
for imgs in listofimgs:
    display(Image(filename=imgs))

# %%
def ques11():
    from IPython.display import Video
    vid=Video(r"D:\PHOTOS\pics\MAH004f03.mp4",embed=True)
    display(vid)
    #don't run big file

# %%
ques11()
# Out:
# <video controls  >
#  <source src="...:\PHOTOS\pics\MAH004f03.mp4" type="None">
#  Your browser does not support the video tag.
#  </video>

# %%
def ques12():
    import shutil
    original=r"C:\Users\USER\OneDrive\Desktop\champ.jpg"
    target=r"E:"
    shutil.move(original,target)
ques12()

# %%
# Out:
# 'E:champ.jpg'

# %%
def ques13():
    import os
    os.system("shutdown /s")

# %%
ques13()

# %%
import smtplib

# %%
server=smtplib.SMTP('smtp.gmail.com',587)

# %%
server.login("srimantofficial@gmail.com","Odisha@11")
# Out:
# ---------------------------------------------------------------------------
# SMTPNotSupportedError                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5316/3487500737.py in <module>
# ----> 1 server.login("srimantofficial@gmail.com","Odisha@11")
#
# ~\anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     714         self.ehlo_or_helo_if_needed()
#     715         if not self.has_extn("auth"):
# --> 716             raise SMTPNotSupportedError(
#     717                 "SMTP AUTH extension not supported by server.")
#     718
#
# SMTPNotSupportedError: SMTP AUTH extension not supported by server.

# %%
def ques14():
    import smtplib
    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.login("youremailusername", "password")
    body = "Hello User,\nThis is to notify you that...."
    server.sendmail("you@gmail.com", "target@example.com", body)

# %%
def ques15():
    import imaplib
    import email
    from email.header import decode_header
    import webbrowser
    import os

    # account credentials
    username = "youremailaddress@provider.com"
    password = "yourpassword"

    def clean(text):
    # clean text for creating a folder
    return "".join(c if c.isalnum() else "_" for c in text)
    # create an IMAP4 class with SSL 
    imap = imaplib.IMAP4_SSL("imap.gmail.com")
    # authenticate
    imap.login(username, password)
    status, messages = imap.select("INBOX")
    # number of top emails to fetch
    N = 3
    # total number of emails
    messages = int(messages[0])
    for i in range(messages, messages-N, -1):
    # fetch the email message by ID
    res, msg = imap.fetch(str(i), "(RFC822)")
    for response in msg:
        if isinstance(response, tuple):
            # parse a bytes email into a message object
            msg = email.message_from_bytes(response[1])
            # decode the email subject
            subject, encoding = decode_header(msg["Subject"])[0]
            if isinstance(subject, bytes):
                # if it's a bytes, decode to str
                subject = subject.decode(encoding)
            # decode email sender
            From, encoding = decode_header(msg.get("From"))[0]
            if isinstance(From, bytes):
                From = From.decode(encoding)
            print("Subject:", subject)
            print("From:", From)
            # if the email message is multipart
            if msg.is_multipart():
                # iterate over email parts
                for part in msg.walk():
                    # extract content type of email
                    content_type = part.get_content_type()
                    content_disposition = str(part.get("Content-Disposition"))
                    try:
                        # get the email body
                        body = part.get_payload(decode=True).decode()
                    except:
                        pass
                    if content_type == "text/plain" and "attachment" not in content_disposition:
                        # print text/plain emails and skip attachments
                        print(body)
                    elif "attachment" in content_disposition:
                        # download attachment
                        filename = part.get_filename()
                        if filename:
                            folder_name = clean(subject)
                            if not os.path.isdir(folder_name):
                                # make a folder for this email (named after the subject)
                                os.mkdir(folder_name)
                            filepath = os.path.join(folder_name, filename)
                            # download attachment and save it
                            open(filepath, "wb").write(part.get_payload(decode=True))
            else:
                # extract content type of email
                content_type = msg.get_content_type()
                # get the email body
                body = msg.get_payload(decode=True).decode()
                if content_type == "text/plain":
                    # print only text email parts
                    print(body)
            if content_type == "text/html":
                # if it's HTML, create a new HTML file and open it in browser
                folder_name = clean(subject)
                if not os.path.isdir(folder_name):
                    # make a folder for this email (named after the subject)
                    os.mkdir(folder_name)
                filename = "index.html"
                filepath = os.path.join(folder_name, filename)
                # write the file
                open(filepath, "w").write(body)
                                # open in the default browser
                webbrowser.open(filepath)
            print("="*100)
# close the connection and logout
imap.close()
imap.logout()
# Out:
#   File "C:\Users\USER\AppData\Local\Temp/ipykernel_5316/312382569.py", line 14
#     return "".join(c if c.isalnum() else "_" for c in text)
#     ^
# IndentationError: expected an indented block

# %%
def ques16():
    from IPython.display import IFrame
    img=IFrame(r"C:\Users\USER\OneDrive\Desktop\aa.pdf",width=600,height=300)
    type(img)

# %%
def ques19():
    import socket
    hostname = socket.gethostname()

# %%
IPAddr = socket.gethostbyname(hostname)

# %%
print("Your Computer Name is:" + hostname)
# Out:
# Your Computer Name is:DESKTOP-2QVA9N0

# %%
print("Your Computer IP Address is:" + IPAddr)
# Out:
# Your Computer IP Address is:192.168.1.5

# %%
pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=15818f04bd4e9b624c51a98c85c38a21931ee914a3c579d66f16717c28e2bde0
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\83\8b\7c\09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
# Successfully built python-docx
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

# %%
document=Document(r"C:\Users\USER\OneDrive\Desktop\kashdshdihdsoihf.docx")

# %%
type(document)
# Out:
# docx.document.Document

# %%
document.paragraphs[0].text
# Out:
# 'Kashdshdihdsoihf'

# %%
indx=0
for i in document.paragraphs:
    indx+=1
    if(len(i.text)>0 ):
       print("\n paragraph",indx,"is ")
       print(i.text)
# Out:
#  paragraph 1 is
# Kashdshdihdsoihf
#
#  paragraph 2 is
# Bdsfgdsgf
#
#  paragraph 3 is
# Dfkdabfjhda
#
#  paragraph 4 is
# Fsd,jshagd
#
#  paragraph 5 is
# ;lsd;lfds;lmflsdmfd;flmlmvflmvlmlmfvlmdf;lmv;lmvlm
#
#  paragraph 6 is
# Dmfd
# dfmSD:Lmfdsfdsf’
#
#  paragraph 7 is
# Dsd;fmds,fmdsdfmdfm
#
#  paragraph 8 is
# Jrorjrff
#
#  paragraph 10 is
# Cdsnf;lmdsf;lf;
#
#  paragraph 11 is
# ;lfmsed’fm’dsf
#
#  paragraph 12 is
# Fmsdlmf’d,f’;c,d;

# %%
def readdocx(name_of_a_file):
    docx_dict={}
    document=Document(name_of_a_file)
    indx=0
    for i in document.paragraphs:
        indx+=1
        if (len(i.text)>0):
            docx_dict[indx]=i.text
    return docx_dict

# %%
readdocx(r"C:\Users\USER\OneDrive\Desktop\kashdshdihdsoihf.docx")
# Out:
# {1: 'Kashdshdihdsoihf',
#  2: 'Bdsfgdsgf',
#  3: 'Dfkdabfjhda',
#  4: 'Fsd,jshagd',
#  5: ';lsd;lfds;lmflsdmfd;flmlmvflmvlmlmfvlmdf;lmv;lmvlm',
#  6: 'Dmfd\ndfmSD:Lmfdsfdsf’',
#  7: 'Dsd;fmds,fmdsdfmdfm',
#  8: 'Jrorjrff',
#  10: 'Cdsnf;lmdsf;lf;',
#  11: ';lfmsed’fm’dsf',
#  12: 'Fmsdlmf’d,f’;c,d;'}

# %%
import os

# %%
ll=os.listdir(r"C:\Users\USER\OneDrive\Desktop")
type(ll[0])
ll[0].endswith
# Out:
# <function str.endswith>

# %%
def fun18(string):
    directory=string
    for filename in os.listdir(directory):
        if filename.endswith(".docx"):
            print(os.path.join(directory,filename))

# %%
fun18(r"C:\Users\USER\OneDrive\Desktop")
# Out:
# C:\Users\USER\OneDrive\Desktop\kashdshdihdsoihf.docx

# %%
pip install PYPDF2
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting PYPDF2
#
# ...
#   Created wheel for PYPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61101 sha256=71bb8e9d32a8a7710f0a323eab05766be773c95eb7f775b240ca4a03f75a504a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\d9\dc\ec\72da68331f30074b9950c1737c23cb8a67484e61498bc9713d
# Successfully built PYPDF2
# ...
